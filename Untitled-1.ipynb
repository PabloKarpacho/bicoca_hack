# %%
import json

a = '''{"raw_text": "# Project Manager
We are looking for an experienced **Project Manager** to join Nozomi and take ownership of delivery for **3 to 5 digital health projects**. In this role, you will be responsible for planning, execution, and control of projects, ensuring delivery timelines, quality, and transparency around resources and budgets.

---

### **Key Responsibilities:**

- Lead and manage **3–5 parallel digital health projects** from kick-off to final delivery.
- Build and maintain project roadmaps, detailed monthly plans, and sprint plans (2-week sprints).
- Ensure on-time delivery, scope control, and stable execution.
- Plan and control **project resources and cashflow**
- Identify, track, and manage project risks and dependencies.
- Facilitate Scrum ceremonies: sprint planning, retrospectives, and internal syncs.
- Coordinate cross-functional teams (engineering, design, product).
- Own delivery communication with partners, including kick-offs, weekly updates, demos, and discussions around timelines and scope.
- Work closely with Product Managers to find optimal trade-offs between scope, timelines, and team capacity.
- Proactively highlight issues and propose practical, actionable solutions.

---

### **Desired Qualifications:**

- 3+ years of experience as an **IT Project Manager** in web (optional) and/or mobile (must) development.
- Proven experience managing **multiple parallel projects** of comparable complexity.
- Strong skills in project planning, delivery execution, and risk management.
- Experience with **resource planning and project cashflow control**.
- Solid, practical understanding of **Agile / Scrum** (beyond running ceremonies).
- High attention to detail and a structured approach to documentation.
- Ability to work with changing requirements and negotiate realistic timelines.
- Confident spoken and written **English (B2+ level or higher)**.

---

### **Bonus Qualifications:**

- Experience working in an agency or studio environment.
- Experience collaborating closely with Product Managers and Tech Leads.
- Background in digital health, health tech, or related industries.
- Experience in business analysis or preparation of project documentation.

---

### **What we offer:**

- **Remote work**
- **Paid sick leave and days off**
- **Clear ownership and autonomy** within your projects
- **Meaningful digital health projects** with real-world impact
- A professional, open, and supportive working environment

---

### **Hiring Process:**

1. Screening interview
2. Interview with the Hiring Manager
3. **Practical assignment or live case session** (for finalists only)
4. Final decision

---

### **This role may not be a good fit if you:**

- Are primarily looking for a Scrum Master or ceremony-focused role
- Prefer working on a single project at a time
- Avoid responsibility for timelines, delivery outcomes, or project economics
- Expect fully defined processes and detailed instructions for every step
- Struggle with ambiguity, changing context, or direct feedback"
}'''

# %%
a = """Data Scientist (моделирование и аналитика)

Локация: Удаленно 
Компания: Axiom Pro
ЗП: обсуждается на собеседовании
Занятость: Полная
                                                                                        
Axiom Pro — международная компания в области подбора и предоставления IT-специалистов и аналитических экспертов для технологических и data-driven компаний.

Сейчас мы ищем Data Scientist (Modeling & Analytics) для нашего партнёра.

Основные обязанности:
- Разработка, поддержка и автоматизация моделей прогнозирования:
вероятности покупки
стоимости страхового полиса
оттока / удержания клиентов
cross-sell и up-sell
next best action
других моделей поведения клиентов
Использование внутренних данных компании, данных переписи населения, агрегированных внешних данных и макроэкономических данных.
- Подготовка рекомендаций для маркетинговых стратегий распределения каналов на основе данных и моделей.
- Проведение продвинутого exploratory data analysis (EDA).
- Анализ интерпретируемости и объяснимости моделей (model interpretability and explainability).
- Использование метрик оценки качества моделей, включая:
precision
recall
F1 score
- Проведение A/B-тестирования, разработка экспериментальных дизайнов и количественных метрик для улучшения моделей.
- Применение требований конфиденциальности и регулирования данных, включая GDPR и CCPA.
- Использование принципов этичного AI, а также методов обнаружения и устранения bias в моделях.
- Проведение анализа эффективности моделей и маркетинговых кампаний как на тестовых выборках, так и после внедрения моделей в продакшн.
- Прогнозирование результатов маркетинговых кампаний на основе моделей и проверка прогнозов по фактическим данным.
- Взаимодействие с архитекторами данных и инженерами данных для обеспечения качества данных:
чистоты
полноты
корректности
пригодности для использования в AI/ML платформах.
- Разработка и поддержка data pipelines.
- Реализация методов feature engineering.
- Поиск, оценка и приобретение дополнительных источников данных для использования в моделировании.
- Проактивное выявление возможностей для улучшения моделей и запуска новых проектов по моделированию.
- Ведение четкой и структурированной документации:
данных
методологий
результатов анализа.
- Автоматизация существующих процессов для повышения общей эффективности.
- Проведение ad-hoc аналитики для поддержки маркетинговых и дистрибуционных инициатив.
- Поиск инновационных подходов и оптимизационных решений, которые могут привести к трансформации бизнеса, увеличению продаж и росту прибыли.
"""

# %%
a = a.replace('\n', '')

# %%
a
# Out:
# 'Data Scientist (моделирование и аналитика)Локация: Удаленно Компания: Axiom ProЗП: обсуждается на собеседованииЗанятость: ПолнаяAxiom Pro — международная компания в области подбора и предоставления IT-специалистов и аналитических экспертов для технологических и data-driven компаний.Сейчас мы ищем Data Scientist (Modeling & Analytics) для нашего партнёра.Основные обязанности:- Разработка, поддержка и автоматизация моделей прогнозирования:вероятности покупкистоимости страхового полисаоттока / удержания клиентовcross-sell и up-sellnext best actionдругих моделей поведения клиентовИспользование внутренних данных компании, данных переписи насе
# ...

# %%
a[31]
# Out:
# '\n'

# %%
json_data = json.loads(a)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 json_data = json.loads(a)
#
# File ~/snap/code/228/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/snap/code/228/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/json/decoder.py:338, in JSONDecoder.decode(self, s, _w)
# ...
